# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("data/pjm_noaa_merged.csv")

# %%
print(df.describe())

# Check missing values
print(df.isna().sum())

print(df.columns)
# Out:
#         Unnamed: 0         value  AWND         PRCP  TAVG  TMAX  TMIN
# count  5000.000000  5.000000e+03   0.0  5797.000000   0.0   0.0   0.0
# mean   2499.500000  1.726320e+06   NaN     0.127630   NaN   NaN   NaN
# std    1443.520003  9.852918e+05   NaN     0.425217   NaN   NaN   NaN
# min       0.000000 -3.881000e+04   NaN     0.000000   NaN   NaN   NaN
# 25%    1249.750000  1.718388e+06   NaN     0.000000   NaN   NaN   NaN
# 50%    2499.500000  2.072470e+06   NaN     0.000000   NaN   NaN   NaN
# 75%    3749.250000  2.392753e+06   NaN     0.070000   NaN   NaN   NaN
# max    4999.000000  3.130576e+06   NaN     5.590000   NaN   NaN   NaN
# Unnamed: 0               845
# period                   845
# respondent               845
# respondent-name          845
# type                     845
# type-name                845
# timezone                 845
# timezone-description     845
# value                    845
# value-units              845
# DATE                       0
# STATION                    0
# NAME                       0
# AWND                    5845
# PRCP                      48
# TAVG                    5845
# TMAX                    5845
# TMIN                    5845
# dtype: int64
# Index(['Unnamed: 0', 'period', 'respondent', 'respondent-name', 'type',
#        'type-name', 'timezone', 'timezone-description', 'value', 'value-units',
#        'DATE', 'STATION', 'NAME', 'AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure DATE is datetime
df['DATE'] = pd.to_datetime(df['DATE'])

plt.figure(figsize=(14,5))
plt.plot(df['DATE'], df['value'], label='Daily Electricity Demand')

# Use month-end ticks ('ME') to reduce clutter
plt.xticks(
    pd.date_range(start=df['DATE'].min(), end=df['DATE'].max(), freq='ME'),
    rotation=45
)

plt.xlabel('Date')
plt.ylabel('Demand (MW)')
plt.title('Daily Electricity Demand (PJM)')
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
