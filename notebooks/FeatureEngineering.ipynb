# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Grab Data

# %%
df = pd.read_csv("../data/pjm_noaa_merged.csv")

# Ensure DATE is datetime
df['DATE'] = pd.to_datetime(df['DATE'])

print(df.shape)
display(df.head(3))
# Out:
# (5000, 16)
#        period subba                                         subba-name parent  \
# 0  2022-04-01    PS  Public Service Electric & Gas of New Jersey zo...    PJM
# 1  2022-04-02    PS  Public Service Electric & Gas of New Jersey zo...    PJM
# 2  2022-04-02    PS  Public Service Electric & Gas of New Jersey zo...    PJM
#
#                 parent-name  timezone     value    value-units       DATE  \
# 0  PJM Interconnection, LLC   Arizona  100418.0  megawatthours 2022-04-01
# 1  PJM Interconnection, LLC   Pacific   90501.0  megawatthours 2022-04-02
# 2  PJM Interconnection, LLC  Mountain   90686.0  megawatthours 2022-04-02
#
#        STATION                   NAME   AWND  PRCP  TAVG  TMAX  TMIN
# 0  US1NJHN0019  LEBANON 3.2 SW, NJ US  17.22  0.24  57.0  70.0  52.0
# 1  US1NJHN0019  LEBANON 3.2 SW, NJ US  11.41  0.01  46.0  58.0  34.0
# 2  US1NJHN0019  LEBANON 3.2 SW, NJ US  11.41  0.01  46.0  58.0  34.0

# %% [markdown]
# # Feature Engineering

# %%
# Ensure DATE is datetime
df['DATE'] = pd.to_datetime(df['DATE'])

# Add Year, Month, Weekday columns
df['Year'] = df['DATE'].dt.year
df['Month'] = df['DATE'].dt.month
df['Weekday'] = df['DATE'].dt.day_name()
